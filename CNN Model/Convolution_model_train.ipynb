# %%
import random
import json
import pickle
import nltk
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Conv1D, GlobalMaxPooling1D
from tensorflow.keras.optimizers import SGD

import numpy as np

# %%
lemmatizer = WordNetLemmatizer()

intents = json.loads(open("data.json").read())

words = []
classes = []
documents = []

ignore_letters = ["?", "!", ".", ","]

for intent in intents["intents"]:
    for symptom in intent["symptoms"]:
        word_list = nltk.word_tokenize(symptom)
        words.extend(word_list)
        documents.append((word_list, intent["name"]))

        if intent["name"] not in classes:
            classes.append(intent["name"])
words = [lemmatizer.lemmatize(word)
        for word in words if word not in ignore_letters]

words = sorted(set(words))
classes = sorted(set(classes))

# %%
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

# %%
dataset = []
template = [0] * len(classes)

for document in documents:
    bag = [0] * len(words)  # Initialize bag with zeros

    word_patterns = document[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]

    for i, word in enumerate(words):
        if word in word_patterns:
            bag[i] = 1

    output_row = list(template)
    output_row[classes.index(document[1])] = 1
    dataset.append((bag, output_row))

random.shuffle(dataset)

train_x = np.array([data[0] for data in dataset])
train_y = np.array([data[1] for data in dataset])

# %%
# Define parameters
input_shape = (len(train_x[0]), 1)  # Input shape would be (length of our input vector, 1)
output_shape = len(train_y[0])  # Output shape would be the number of intent classes

# Reshape the training data to fit the model
train_x = np.array(train_x).reshape(len(train_x), len(train_x[0]), 1)

# Define model
model = Sequential()
model.add(Conv1D(256, 5, activation='relu', input_shape=input_shape))
model.add(GlobalMaxPooling1D())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(output_shape, activation='softmax'))

# Compile model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Training model
model.fit(train_x, np.array(train_y), epochs=200, batch_size=5, verbose=2)

# Save model
model.save('medical_chatbot_model.h5')
# Out:
# Epoch 1/200
# 314/314 - 2s - loss: 5.6093 - accuracy: 0.0038 - 2s/epoch - 7ms/step
# Epoch 2/200
# 314/314 - 2s - loss: 5.5985 - accuracy: 0.0089 - 2s/epoch - 6ms/step
# Epoch 3/200
# 314/314 - 2s - loss: 5.5819 - accuracy: 0.0102 - 2s/epoch - 6ms/step
# Epoch 4/200
# 314/314 - 2s - loss: 5.5751 - accuracy: 0.0109 - 2s/epoch - 6ms/step
# Epoch 5/200
# 314/314 - 2s - loss: 5.5680 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 6/200
# 314/314 - 2s - loss: 5.5652 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 7/200
# 314/314 - 2s - loss: 5.5639 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 8/200
# 314/314 - 2s - loss: 5.5583 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 9/200
# 314/314 - 2s - loss: 5.5565 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 10/200
# 314/314 - 2s - loss: 5.5557 - accuracy: 0.0109 - 2s/epoch - 6ms/step
# Epoch 11/200
# 314/314 - 2s - loss: 5.5559 - accuracy: 0.0109 - 2s/epoch - 6ms/step
# Epoch 12/200
# 314/314 - 2s - loss: 5.5518 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 13/200
# 314/314 - 2s - loss: 5.5519 - accuracy: 0.0109 - 2s/epoch - 6ms/step
# Epoch 14/200
# 314/314 - 2s - loss: 5.5526 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 15/200
# 314/314 - 2s - loss: 5.5492 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 16/200
# 314/314 - 2s - loss: 5.5504 - accuracy: 0.0109 - 2s/epoch - 6ms/step
# Epoch 17/200
# 314/314 - 2s - loss: 5.5482 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 18/200
# 314/314 - 2s - loss: 5.5502 - accuracy: 0.0089 - 2s/epoch - 6ms/step
# Epoch 19/200
# 314/314 - 2s - loss: 5.5496 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 20/200
# 314/314 - 2s - loss: 5.5476 - accuracy: 0.0096 - 2s/epoch - 6ms/step
# Epoch 21/200
# 314/314 - 2s - loss: 5.5482 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch
- accuracy: 0.0134 - 2s/epoch - 6ms/step
# Epoch 163/200
# 314/314 - 2s - loss: 5.4791 - accuracy: 0.0121 - 2s/epoch - 7ms/step
# Epoch 164/200
# 314/314 - 2s - loss: 5.4789 - accuracy: 0.0121 - 2s/epoch - 6ms/step
# Epoch 165/200
# 314/314 - 2s - loss: 5.4806 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 166/200
# 314/314 - 2s - loss: 5.4811 - accuracy: 0.0109 - 2s/epoch - 6ms/step
# Epoch 167/200
# 314/314 - 2s - loss: 5.4883 - accuracy: 0.0134 - 2s/epoch - 6ms/step
# Epoch 168/200
# 314/314 - 2s - loss: 5.4815 - accuracy: 0.0140 - 2s/epoch - 6ms/step
# Epoch 169/200
# 314/314 - 2s - loss: 5.4804 - accuracy: 0.0128 - 2s/epoch - 6ms/step
# Epoch 170/200
# 314/314 - 2s - loss: 5.4860 - accuracy: 0.0140 - 2s/epoch - 7ms/step
# Epoch 171/200
# 314/314 - 2s - loss: 5.4838 - accuracy: 0.0121 - 2s/epoch - 7ms/step
# Epoch 172/200
# 314/314 - 2s - loss: 5.4771 - accuracy: 0.0128 - 2s/epoch - 6ms/step
# Epoch 173/200
# 314/314 - 2s - loss: 5.4865 - accuracy: 0.0121 - 2s/epoch - 6ms/step
# Epoch 174/200
# 314/314 - 2s - loss: 5.4833 - accuracy: 0.0134 - 2s/epoch - 6ms/step
# Epoch 175/200
# 314/314 - 2s - loss: 5.4785 - accuracy: 0.0128 - 2s/epoch - 6ms/step
# Epoch 176/200
# 314/314 - 2s - loss: 5.4817 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 177/200
# 314/314 - 2s - loss: 5.4834 - accuracy: 0.0115 - 2s/epoch - 7ms/step
# Epoch 178/200
# 314/314 - 2s - loss: 5.4841 - accuracy: 0.0128 - 2s/epoch - 6ms/step
# Epoch 179/200
# 314/314 - 2s - loss: 5.4847 - accuracy: 0.0121 - 2s/epoch - 6ms/step
# Epoch 180/200
# 314/314 - 2s - loss: 5.4817 - accuracy: 0.0128 - 2s/epoch - 6ms/step
# Epoch 181/200
# 314/314 - 2s - loss: 5.4810 - accuracy: 0.0121 - 2s/epoch - 6ms/step
# Epoch 182/200
# 314/314 - 2s - loss: 5.4862 - accuracy: 0.0128 - 2s/epoch - 6ms/step
# Epoch 183/200
# 314/314 - 2s - loss: 5.4828 - accuracy: 0.0128 - 2s/epoch - 6ms/step
# Epoch 184/200
# 314/314 - 2s - loss: 5.4800 - accuracy: 0.0140 - 2s/epoch - 6ms/step
# Epoch 185/200
# 314/314 - 2s - loss: 5.4876 - accuracy: 0.0134 - 2s/epoch - 7ms/step
# Epoch 186/200
# 314/314 - 2s - loss: 5.4827 - accuracy: 0.0115 - 2s/epoch - 7ms/step
# Epoch 187/200
# 314/314 - 2s - loss: 5.4808 - accuracy: 0.0121 - 2s/epoch - 7ms/step
# Epoch 188/200
# 314/314 - 2s - loss: 5.4850 - accuracy: 0.0121 - 2s/epoch - 6ms/step
# Epoch 189/200
# 314/314 - 2s - loss: 5.4857 - accuracy: 0.0121 - 2s/epoch - 6ms/step
# Epoch 190/200
# 314/314 - 2s - loss: 5.4876 - accuracy: 0.0134 - 2s/epoch - 6ms/step
# Epoch 191/200
# 314/314 - 2s - loss: 5.4864 - accuracy: 0.0121 - 2s/epoch - 6ms/step
# Epoch 192/200
# 314/314 - 2s - loss: 5.4850 - accuracy: 0.0134 - 2s/epoch - 6ms/step
# Epoch 193/200
# 314/314 - 2s - loss: 5.4828 - accuracy: 0.0121 - 2s/epoch - 7ms/step
# Epoch 194/200
# 314/314 - 2s - loss: 5.4803 - accuracy: 0.0121 - 2s/epoch - 7ms/step
# Epoch 195/200
# 314/314 - 2s - loss: 5.4819 - accuracy: 0.0115 - 2s/epoch - 6ms/step
# Epoch 196/200
# 314/314 - 2s - loss: 5.4839 - accuracy: 0.0121 - 2s/epoch - 6ms/step
# Epoch 197/200
# 314/314 - 2s - loss: 5.4795 - accuracy: 0.0140 - 2s/epoch - 6ms/step
# Epoch 198/200
# 314/314 - 2s - loss: 5.4804 - accuracy: 0.0128 - 2s/epoch - 6ms/step
# Epoch 199/200
# 314/314 - 2s - loss: 5.4861 - accuracy: 0.0128 - 2s/epoch - 6ms/step
# Epoch 200/200
# 314/314 - 2s - loss: 5.4826 - accuracy: 0.0128 - 2s/epoch - 6ms/step
